# %% [markdown]
# <a href="https://colab.research.google.com/github/adhang/data-science-digital-skola/blob/update/16.%20Advanced%20Visualization/Learn%20-%20Advanced%20Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Visualization
# Author: Adhang Muntaha Muhammad
#
# [![LinkedIn](https://img.shields.io/badge/linkedin-0077B5?style=for-the-badge&logo=linkedin&logoColor=white&link=https://www.linkedin.com/in/adhangmuntaha/)](https://www.linkedin.com/in/adhangmuntaha/)
# [![GitHub](https://img.shields.io/badge/github-121011?style=for-the-badge&logo=github&logoColor=white&link=https://github.com/adhang)](https://github.com/adhang)
# [![Kaggle](https://img.shields.io/badge/kaggle-20BEFF?style=for-the-badge&logo=kaggle&logoColor=white&link=https://www.kaggle.com/adhang)](https://www.kaggle.com/adhang)
# [![Tableau](https://img.shields.io/badge/tableau-E97627?style=for-the-badge&logo=tableau&logoColor=white&link=https://public.tableau.com/app/profile/adhang)](https://public.tableau.com/app/profile/adhang)
# ___
#
# **Contents**
# - Seaborn
# - Folium
# - Wordcloud

# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Importing Library

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# set plot to sns theme, even if we use matplotlib
sns.set_theme(style='darkgrid')

# another way to set the style:
# sns.set_style('darkgrid')

# %% [markdown]
# ## Reading Dataset

# %%
data = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# - `total_bill` - total charged (USD)
# - `tip` - tips (USD)
# - `sex` - gender (Female, Male)
# - `smoker` - smoker or not (Yes, No)
# - `day` - day (Sun, Sat, Thur, Fri)
# - `size` - number of people in visitor group

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ## Line Plot

# %% [markdown]
# ### Basic Line Plot

# %%
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

fig, ax = plt.subplots(figsize=(9,6))

sns.lineplot(x=xpoints, y=ypoints, ax=ax)

plt.show()

# %% [markdown]
# ### Regression Plot

# %% [markdown]
# #### regplot

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.regplot(data=data, x='total_bill', y='tip', ax=ax)

# plt.show()

# %% [markdown]
# #### lmplot

# %%
# same as regplot but using FacetGrid
sns.lmplot(data=data, x='total_bill', y='tip')

# plt.show()

# %%
# same as regplot but using FacetGrid
sns.lmplot(data=data, x='total_bill', y='tip', hue='smoker')

# plt.show()

# %%
# same as regplot but using FacetGrid
sns.lmplot(data=data, x='total_bill', y='tip', hue='time')

# plt.show()

# %%
# same as regplot but using FacetGrid
sns.lmplot(data=data, x='total_bill', y='tip', hue='sex')

# plt.show()

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ### Basic Scatter Plot

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.scatterplot(data=data, x='total_bill', y='tip', hue='sex', ax=ax)

plt.show()

# %%
sns.lmplot(data=data, x='total_bill', y='tip', hue='sex', fit_reg=False)

# %% [markdown]
# ### Bubble Chart

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.scatterplot(data=data, x='total_bill', y='tip', hue='sex', size='size', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.scatterplot(data=data, x='total_bill', y='tip', hue='sex', size='size', ax=ax)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ### Vertical Bar Chart

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.barplot(data=data, x='day', y='total_bill', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.barplot(data=data, x='day', y='total_bill', hue='smoker', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.barplot(data=data, x='sex', y='total_bill', hue='day', ax=ax)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# ### Horizontal Bar Chart

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.barplot(data=data, x='total_bill', y='day', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.barplot(data=data, x='total_bill', y='day', hue='smoker', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.barplot(data=data, x='total_bill', y='sex', hue='day', ax=ax)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Categorical Plot

# %% [markdown]
# ### Basic Categorical Plot

# %%
sns.catplot(data=data, x='day', y='tip')

# %%
sns.catplot(data=data, x='day', y='tip', hue='sex')

# %%
sns.catplot(data=data, x='time', y='tip', hue='sex', col='day')

# %% [markdown]
# ### Different Kind Plot

# %% [markdown]
# #### Violin Plot

# %%
sns.catplot(data=data, x='day', y='tip', hue='sex', col='smoker', kind='violin')

# %% [markdown]
# #### Box Plot

# %%
sns.catplot(data=data, x='day', y='tip', hue='sex', col='smoker', kind='box')

# %% [markdown]
# ## Distribution Plot

# %% [markdown]
# ### Histogram

# %%
sns.displot(data=data, x='total_bill')

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.histplot(data=data, x='total_bill', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.histplot(data=data, x='total_bill', hue='sex', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.histplot(data=data, x='total_bill', hue='sex', multiple='stack', ax=ax)

plt.show()

# %% [markdown]
# ### Density

# %%
sns.displot(data=data, x='total_bill', kind='kde')

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.kdeplot(data=data, x='total_bill', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.kdeplot(data=data, x='total_bill', hue='sex', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.kdeplot(data=data, x='total_bill', hue='sex', fill=True, ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.kdeplot(data=data, x='total_bill', multiple='stack', hue='sex', ax=ax)

plt.show()

# %% [markdown]
# ### Histogram + Density

# %%
sns.displot(data=data, x='total_bill', kde=True)

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.histplot(data=data, x='total_bill', kde=True, ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.histplot(data=data, x='total_bill', hue='sex', multiple='stack', fill=True, kde=True, ax=ax)

plt.show()

# %% [markdown]
# ## Box Plot

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.boxplot(data=data, x='day', y='total_bill', ax=ax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.boxplot(data=data, x='day', y='total_bill', hue='smoker', ax=ax)

plt.show()

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(data=data, hue='sex')

# %% [markdown]
# ## Heatmap

# %%
fig, ax = plt.subplots(figsize=(9,6))

sns.heatmap(data.corr(), annot=True, ax=ax)

plt.show()

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot(data=data, x='total_bill', y='tip', color='#4CB391')

# %%
sns.jointplot(data=data, x='total_bill', y='tip', kind='hex', color='#4CB391')

# %% [markdown]
# # Folium

# %% [markdown]
# ## Installing Library

# %%
# !pip install folium

# %% [markdown]
# ## Importing Library

# %%
import folium

# %% [markdown]
# ## Showing Map

# %%
# Source https://www.analyticsvidhya.com/blog/2020/06/guide-geospatial-analysis-folium-python

m = folium.Map(location=[-6.556731, 106.725945], zoom_start=16)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Marker

# %%
m = folium.Map(location=[-6.556731, 106.725945], zoom_start=16)

tooltip = 'Click me!'
folium.Marker( [-6.557373133349863, 106.7312903], popup='<i>FMIPA</i>', tooltip=tooltip).add_to(m)
folium.Marker( [-6.555666484674371, 106.72528758665811], popup='<i>Masjid Al-Hurriyah</i>', tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Choropleth

# %%
# source: https://python-visualization.github.io/folium/quickstart.html

import pandas as pd

url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'

state_geo = f'{url}/us-states.json'
state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)

state_data.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo
# Out:
# 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json'

# %%
m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)',
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# # Wordcloud

# %% [markdown]
# ## Installing Library

# %%
# Source https://towardsdatascience.com/simple-wordcloud-in-python-2ae54a9f58e5
# Import packages
# !pip install wikipedia
# Out:
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=6c3e6a0e4a96cfa41f6f502bd1878ccf950de31283bb6d88ad1a6dfcc0b01811
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# ...

# %% [markdown]
# ## Importing Libraries

# %%
from wordcloud import WordCloud, STOPWORDS
import wikipedia
import re

# %% [markdown]
# ## Wordcloud

# %%
# Specify the title of the Wikipedia page
wiki = wikipedia.page('Web scraping')
# Extract the plain text content of the page
text = wiki.content
# Clean text
text = re.sub(r'==.*?==+', '', text)
text = text.replace('\n', '')

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(12, 9))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis('off');

# %%
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='white', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate(text)
# Plot
plot_cloud(wordcloud)
