# %% [markdown]
# <a href="https://colab.research.google.com/github/adhang/data-science-digitalskola/blob/update/05.%20Introduction%20to%20Pandas%20and%20Basic%20Dataframe/Learn_Introduction_to_Pandas_and_Basic_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Pandas and Basic Dataframe
# Author: Adhang Muntaha Muhammad
#
# [GitHub](https://github.com/adhang)
# [LinkedIn](https://www.linkedin.com/in/adhangmuntaha/)
# ___
# **Contents**
# - Create Dataframe
#   - Using List
#   - Using Tuple
#   - Using Numpy Array
#   - Using Pandas Series
# - Reading Dataset on Google Colab
#   - Upload file to Google Colab
#   - From Google Drive
# - Reading Dataset on Local Directory
#   - CSV format
#   - Ms Excel format

# %% [markdown]
# ## Create Dataframe

# %%
# Import Pandas library
import pandas as pd

pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# ### Using List

# %%
# Create list
list_name = ['Adhang', 'Muntaha', 'Muhammad']
list_age = [23, 24, 25]
list_city = ['Jogja', 'Jakarta', 'Palembang']

# Combine using zip function
list_zip = list(zip(list_name, list_age, list_city))
list_zip
# Out:
# [('Adhang', 23, 'Jogja'),
#  ('Muntaha', 24, 'Jakarta'),
#  ('Muhammad', 25, 'Palembang')]

# %%
# Create dataframe
df_list = pd.DataFrame(list_zip,
                       columns=['Name', 'Age', 'City'])
df_list
# Out:
#        Name  Age       City
# 0    Adhang   23      Jogja
# 1   Muntaha   24    Jakarta
# 2  Muhammad   25  Palembang

# %%
df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# ### Using Tuple

# %%
# Create tuple (with zipped format)
tuple_1 = ('Adhang', 23, 'Jogja')
tuple_2 = ('Muntaha', 24, 'Jakarta')
tuple_3 = ('Muhammad', 25, 'Palembang')

# %%
# Create dataframe
df_tuple = pd.DataFrame([tuple_1,
                         tuple_2,
                         tuple_3],
                        columns=['Name', 'Age', 'City'])
df_tuple
# Out:
#        Name  Age       City
# 0    Adhang   23      Jogja
# 1   Muntaha   24    Jakarta
# 2  Muhammad   25  Palembang

# %%
df_tuple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# ### Using Numpy Array

# %%
import numpy as np

# Create numpy array
arr = np.array([['Adhang', 23, 'Jogja'],
                ['Muntaha', 24, 'Jakarta'],
                ['Muhammad', 25, 'Palembang']])
arr
# Out:
# array([['Adhang', '23', 'Jogja'],
#        ['Muntaha', '24', 'Jakarta'],
#        ['Muhammad', '25', 'Palembang']], dtype='<U9')

# %%
# Create dataframe
df_array = pd.DataFrame(arr, columns=['Name', 'Age', 'City'])
df_array
# Out:
#        Name Age       City
# 0    Adhang  23      Jogja
# 1   Muntaha  24    Jakarta
# 2  Muhammad  25  Palembang

# %%
df_array.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      object
#  2   City    3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %% [markdown]
# ### Using Pandas Series
# **Note:**
# Pandas Series items must have same data type

# %%
# Create pandas series
series_1 = pd.Series(['Adhang', 'Muntaha', 'Muhammad'])
series_2 = pd.Series([23, 24, 25])
series_3 = pd.Series(['Jogja', 'Jakarta', 'Palembang'])

# %%
# Create dataframe
df_series = pd.DataFrame({'Name':series_1,
                          'Age':series_2,
                          'City':series_3})
df_series
# Out:
#        Name  Age       City
# 0    Adhang   23      Jogja
# 1   Muntaha   24    Jakarta
# 2  Muhammad   25  Palembang

# %%
df_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# ## Reading Dataset on Google Colab
# Some ways to add dataset on Google Colab:
# - Upload file to Google Colab
# - From Google Drive
# - From BigQuery
# - From GitHub

# %% [markdown]
# ### Upload file to Google Colab

# %%
from google.colab import files

# %%
files.upload()

# See the uploaded file on the file list panel (left)
# Out:
#      <input type="file" id="files-7954f63f-5573-4a18-99ae-53bd846c8842" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7954f63f-5573-4a18-99ae-53bd846c8842">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bq-results-20220127-145129-lengkap provinsi.csv to bq-results-20220127-145129-lengkap provinsi.csv
# {'bq-results-20220127-145129-lengkap provinsi.csv': b'date,location_key,country_name,subregion1_name,aggregation_level,latitude,longitude,new_confirmed,new_deceased,new_recovered,cumulative_confirmed,cumulative_deceased,cumulative_recovered,new_persons_vaccinated,new_persons_fully_vaccinated,cumulative_persons_vaccinated,cumulative_persons_fully_vaccinated,population\n2022-01-26,ID_AC,Indonesia,Aceh,1,4.3,96.9,,,,,,,,,,,5371532\n2022-01-26,ID_KI,Indonesia,East Kalimantan,1,1.05,116.316667,,,,,,,,,,,3721389\n2022-01-26,ID_MA,Indonesia,Maluku,1,-3.705,128.17,,,,,,,,,,,1802870\n2022-01-26,ID_PB,Indonesia,West Papua,1,-1.801389,133.670556,,,,,,,,,,,959617\n2022-01-26,ID_SS,Indonesia,South Sumatra,1,-2.75,103.833333,,,,,,,,,,,8470683\n2022-01-26,ID_YO,Indonesia,Yogyakarta,1,-7.801389,110.364444,,,,,,,,,,,3842932\n2022-01-26,ID_BE,Indonesia,Bengkulu,1,-3.8,102.25,,,,,,,,,,,1991838\n2022-01-26,ID_KB,Indonesia,West Kalimantan,1,0,110.5,,,,,,,,,,,5069127\n2022-01-26,ID_KS,Indonesia,South Kalimantan,1,-2.5,115.5,,,,,,,,,,,4244096\n2022-01-26,ID_KR,Indonesia,Riau Islands,1,0.9,104.45,,,,,,,,,,,2189653\n2022-01-26,ID_JT,Indonesia,Central Java,1,-7.5,110,,,,,,,,,,,34718204\n2022-01-26,ID_BB,Indonesia,Bangka Belitung Islands,1,-2.133333,106.116667,,,,,,,,,,,1488792\n2022-01-26,ID_GO,Indonesia,Gorontalo,1,0.666667,123,,,,,,,,,,,1202631\n2022-01-26,ID_SN,Indonesia,South Sulawesi,1,-4.333333,120.25,,,,,,,,,,,8851240\n2022-01-26,ID_BA,Indonesia,Bali,1,-8.5,115,,,,,,,,,,,4336000\n2022-01-26,ID_BT,Indonesia,Banten,1,-6.5,106.25,,,,,,,,,,,12927316\n2022-01-26,ID_NB,Indonesia,West Nusa Tenggara,1,-8.583333,116.116667,,,,,,,,,,,5013687\n2022-01-26,ID_JK,Indonesia,Jakarta,1,-6.21462,106.84513,,,,,,,,,,,10557810\n2022-01-26,ID_MU,Indonesia,North Maluku,1,0.783333,127.366667,,,,,,,,,,,1255771\n2022-01-26,ID_SG,Indonesia,Southeast Sulawesi,1,-3.95,122.5,,,,,,,,,,,2704737\n2022-01-26,ID_JA,Indonesia,Jambi,1,-1.583333,103.616667,,,,,,,,,,,3624579\n2022-01-26,ID_LA,Indonesia,Lampung,1,-5.45,105.266667,,,,,,,,,,,8447737\n2022-01-26,ID_KU,Indonesia,North Kalimantan,1,3.415083,116.463333,,,,,,,,,,,742245\n2022-01-26,ID_NT,Indonesia,East Nusa Tenggara,1,-10.183333,123.583333,,,,,,,,,,,5456203\n2022-01-26,ID,Indonesia,,0,-2,118,7010,7,2582,4301193,144254,4127662,,,,,273523621\n2022-01-26,ID_JI,Indonesia,East Java,1,-7.939167,112.952778,,,,,,,,,,,39698631\n2022-01-26,ID_RI,Indonesia,Riau,1,0.533333,101.45,,,,,,,,,,,6971745\n2022-01-26,ID_PA,Indonesia,Papua,1,-4,138,,,,,,,,,,,3379302\n2022-01-26,ID_SA,Indonesia,North Sulawesi,1,1.25,124.833333,,,,,,,,,,,2506981\n2022-01-26,ID_SR,Indonesia,West Sulawesi,1,-2.683333,118.9,,,,,,,,,,,1380256\n2022-01-26,ID_SU,Indonesia,North Sumatra,1,2,99,,,,,,,,,,,14562549\n2022-01-26,ID_SB,Indonesia,West Sumatra,1,-1,100.5,,,,,,,,,,,5441197\n2022-01-26,ID_JB,Indonesia,West Java,1,-6.75,107.5,,,,,,,,,,,49316712\n2022-01-26,ID_KT,Indonesia,Central Kalimantan,1,-2.216667,113.916667,,,,,,,,,,,2714000\n2022-01-26,ID_ST,Indonesia,Central Sulawesi,1,-1,121,,,,,,,,,,,3054023\n2022-01-25,ID_KB,Indonesia,West Kalimantan,1,0,110.5,,,,,,,,,,,5069127\n2022-01-25,ID_AC,Indonesia,Aceh,1,4.3,96.9,,,,,,,,,,,5371532\n2022-01-25,ID_SB,Indonesia,West Sumatra,1,-1,100.5,,,,,,,,,,,5441197\n2022-01-25,ID_KR,Indonesia,Riau Islands,1,0.9,104.45,,,,,,,,,,,2189653\n2022-01-25,ID_PB,Indonesia,West Papua,1,-1.801389,133.670556,,,,,,,,,,,959617\n2022-01-25,ID_KI,Indonesia,East Kalimantan,1,1.05,116.316667,,,,,,,,,,,3721389\n2022-01-25,ID_MA,Indonesia,Maluku,1,-3.705,128.17,,,,,,,,,,,1802870\n2022-01-25,ID_SS,Indonesia,South Sumatra,1,-2.75,103.833333,,,,,,,,,,,8470683\n2022-01-25,ID_BB,Indonesia,Bangka Belitung Islands,1,-2.133333,106.116667,,,,,,,,,,,1488792\n2022-01-25,ID_GO,Indonesia,Gorontalo,1,0.666667,123,,,,,,,,,,,1202631\n2022-01-25,ID_JB,Indonesia,West Java,1,-6.75,107.5,,,,,,,,,,,49316712\n2022-01-25,ID_KU,Indonesia,North Kalimantan,1,3.415083,116.463333,,,,,,,,,,,742245\n2022-01-25,ID_MU,Indonesia,North Maluku,1,0.783333,127.366667,,,,,,,,,,,1255771 ...

# %%
read_colab = pd.read_csv('bq-results-20220127-145129-lengkap provinsi.csv')
read_colab.head()
# Out:
#          date location_key  ... cumulative_persons_fully_vaccinated population
# 0  2022-01-26        ID_AC  ...                                 NaN    5371532
# 1  2022-01-26        ID_KI  ...                                 NaN    3721389
# 2  2022-01-26        ID_MA  ...                                 NaN    1802870
# 3  2022-01-26        ID_PB  ...                                 NaN     959617
# 4  2022-01-26        ID_SS  ...                                 NaN    8470683
#
# [5 rows x 18 columns]

# %% [markdown]
# ### From Google Drive

# %%
from google.colab import drive

# mount drive, grant the permmission to access files from google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
read_gdrive = pd.read_csv('/content/drive/MyDrive/BigQuery - Covid19 Open Data/bq-results-20220127-145129-covid open data/bq-results-20220127-145129-otb5etd75lr.csv')
read_gdrive.head()
# Out:
#          date location_key  ... cumulative_persons_fully_vaccinated population
# 0  2022-01-26        ID_AC  ...                                 NaN    5371532
# 1  2022-01-26        ID_KI  ...                                 NaN    3721389
# 2  2022-01-26        ID_MA  ...                                 NaN    1802870
# 3  2022-01-26        ID_PB  ...                                 NaN     959617
# 4  2022-01-26        ID_SS  ...                                 NaN    8470683
#
# [5 rows x 18 columns]

# %% [markdown]
# ## Reading Dataset on Local
# File format:
# - CSV
# - Ms Excel
# - JSON
# - XML
# - etc
#
# More reference:
# [Pandas I/O Tools](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)
#
# **Notes**: Since the scripts on the next 2 cells are run on Jupyter Notebook, the dataset can't be displayed.
#
# Alternatively, if you use Google Colab, try to upload the file to Google Colab or Google Drive.

# %% [markdown]
# ### CSV Format

# %%
read_csv = pd.read_csv('/dataset/BiqQuery Covid Open Data - Indonesia.csv')
read_csv.head()

# %% [markdown]
# ### Ms Excel Format

# %%
read_excel = pd.read_excel('/dataset/BiqQuery Covid Open Data - Indonesia.xls', sheet_name='raw_data')
read_excel.head()
