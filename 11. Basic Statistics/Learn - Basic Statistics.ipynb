# %% [markdown]
# <a href="https://colab.research.google.com/github/adhang/data-science-digitalskola/blob/update/11.%20Basic%20Statistics/Learn%20-%20Basic%20Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Statistics
# Author: Adhang Muntaha Muhammad
#
# [![LinkedIn](https://img.shields.io/badge/linkedin-0077B5?style=for-the-badge&logo=linkedin&logoColor=white&link=https://www.linkedin.com/in/adhangmuntaha/)](https://www.linkedin.com/in/adhangmuntaha/)
# [![GitHub](https://img.shields.io/badge/github-121011?style=for-the-badge&logo=github&logoColor=white&link=https://github.com/adhang)](https://github.com/adhang)
# [![Kaggle](https://img.shields.io/badge/kaggle-20BEFF?style=for-the-badge&logo=kaggle&logoColor=white&link=https://www.kaggle.com/adhang)](https://www.kaggle.com/adhang)
# [![Tableau](https://img.shields.io/badge/tableau-E97627?style=for-the-badge&logo=tableau&logoColor=white&link=https://public.tableau.com/app/profile/adhang)](https://public.tableau.com/app/profile/adhang)
# ___
# **Contents**
# - Importing Libraries
# - Reading Dataset
# - Dataset Overview
# - Basic EDA

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

sns.set_style('whitegrid')
plt.rc('patch', edgecolor='black')
sns.set_context("notebook", font_scale=1.3, rc={"lines.linewidth": 1.5})

# %% [markdown]
# # Reading Dataset

# %%
file_path = '/content/drive/MyDrive/Digital Skola/Learn/dataset/kaggle_titanic.csv'

data = pd.read_csv(file_path)
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# # Dataset Overview

# %% [markdown]
# ## Basic Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Null Values

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Drop Column

# %%
data.drop(['Ticket','Cabin'], axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 69.7+ KB

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %% [markdown]
# # Basic EDA

# %% [markdown]
# ## Count Plot

# %%
f,ax=plt.subplots(1,3,figsize=(18,6))

sns.countplot(data.Survived,ax=ax[0])
ax[0].set_title('Survived')

sns.countplot(data.Sex,hue=data.Survived,ax=ax[1])
ax[1].set_title('Sex <--> Survived')

sns.countplot(data.Pclass,hue=data.Survived,ax=ax[2])
ax[2].set_title('Pclass <--> Survived')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Crosstab & Pivot Table

# %%
pd.crosstab([data.Sex,data.Pclass],data.Survived,margins = True).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_c7504_row0_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c7504_row0_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_c7504_row0_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_c7504_row1_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c7504_row1_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_c7504_row1_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c7504_row2_col0, #T_c7504_row3_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_c7504_row2_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_c7504_row2_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_c7504_row3_col0, #T_c7504_row3_col2, #T_c7504_row5_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_c7504_row4_col0 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_c7504_row4_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c7504_row4_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c7504_row5_col0 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_c7504_row5_col2 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_c7504_row6_col0, #T_c7504_row6_col1, #T_c7504_row6_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7504_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7504_level0_row0" class="row_heading level0 row0" rowspan="3">female</th>
#       <th id="T_c7504_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_c7504_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_c7504_row0_col1" class="data row0 col1" >91</td>
#       <td id="T_c7504_row0_col2" class="data row0 col2" >94</td>
#     </tr>
#     <tr>
#       <th id="T_c7504_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_c7504_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_c7504_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_c7504_row1_col2" class="data row1 col2" >76</td>
#     </tr>
#     <tr>
#       <th id="T_c7504_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_c7504_row2_col0" class="data row2 col0" >72</td>
#       <td id="T_c7504_row2_col1" class="data row2 col1" >72</td>
#       <td id="T_c7504_row2_col2" class="data row2 col2" >144</td>
#     </tr>
#     <tr>
#       <th id="T_c7504_level0_row3" class="row_heading level0 row3" rowspan="3">male</th>
#       <th id="T_c7504_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_c7504_row3_col0" class="data row3 col0" >77</td>
#       <td id="T_c7504_row3_col1" class="data row3 col1" >45</td>
#       <td id="T_c7504_row3_col2" class="data row3 col2" >122</td>
#     </tr>
#     <tr>
#       <th id="T_c7504_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_c7504_row4_col0" class="data row4 col0" >91</td>
#       <td id="T_c7504_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_c7504_row4_col2" class="data row4 col2" >108</td>
#     </tr>
#     <tr>
#       <th id="T_c7504_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_c7504_row5_col0" class="data row5 col0" >300</td>
#       <td id="T_c7504_row5_col1" class="data row5 col1" >47</td>
#       <td id="T_c7504_row5_col2" class="data row5 col2" >347</td>
#     </tr>
#     <tr>
#       <th id="T_c7504_level0_row6" class="row_heading level0 row6" >All</th>
#       <th id="T_c7504_level1_row6" class="row_heading level1 row6" ></th>
#       <td id="T_c7504_row6_col0" class="data row6 col0" >549</td>
#       <td id="T_c7504_row6_col1" class="data row6 col1" >342</td>
#       <td id="T_c7504_row6_col2" class="data row6 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([data.Embarked,data.Pclass],data.Survived,margins = True).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_84e60_row0_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_84e60_row0_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_84e60_row0_col2, #T_84e60_row6_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_84e60_row1_col0, #T_84e60_row1_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_84e60_row1_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_84e60_row2_col0, #T_84e60_row2_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_84e60_row2_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_84e60_row3_col0, #T_84e60_row3_col1, #T_84e60_row3_col2, #T_84e60_row4_col0, #T_84e60_row4_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_84e60_row4_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_84e60_row5_col0, #T_84e60_row5_col1, #T_84e60_row5_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_84e60_row6_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_84e60_row6_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_84e60_row7_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_84e60_row7_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_84e60_row7_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_84e60_row8_col0 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_84e60_row8_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_84e60_row8_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_84e60_row9_col0, #T_84e60_row9_col1, #T_84e60_row9_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84e60_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84e60_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_84e60_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_84e60_row0_col0" class="data row0 col0" >26</td>
#       <td id="T_84e60_row0_col1" class="data row0 col1" >59</td>
#       <td id="T_84e60_row0_col2" class="data row0 col2" >85</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_84e60_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_84e60_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_84e60_row1_col2" class="data row1 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_84e60_row2_col0" class="data row2 col0" >41</td>
#       <td id="T_84e60_row2_col1" class="data row2 col1" >25</td>
#       <td id="T_84e60_row2_col2" class="data row2 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_84e60_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_84e60_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_84e60_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_84e60_row3_col2" class="data row3 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_84e60_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_84e60_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_84e60_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_84e60_row5_col0" class="data row5 col0" >45</td>
#       <td id="T_84e60_row5_col1" class="data row5 col1" >27</td>
#       <td id="T_84e60_row5_col2" class="data row5 col2" >72</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_84e60_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_84e60_row6_col0" class="data row6 col0" >53</td>
#       <td id="T_84e60_row6_col1" class="data row6 col1" >74</td>
#       <td id="T_84e60_row6_col2" class="data row6 col2" >127</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_84e60_row7_col0" class="data row7 col0" >88</td>
#       <td id="T_84e60_row7_col1" class="data row7 col1" >76</td>
#       <td id="T_84e60_row7_col2" class="data row7 col2" >164</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_84e60_row8_col0" class="data row8 col0" >286</td>
#       <td id="T_84e60_row8_col1" class="data row8 col1" >67</td>
#       <td id="T_84e60_row8_col2" class="data row8 col2" >353</td>
#     </tr>
#     <tr>
#       <th id="T_84e60_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_84e60_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_84e60_row9_col0" class="data row9 col0" >549</td>
#       <td id="T_84e60_row9_col1" class="data row9 col1" >340</td>
#       <td id="T_84e60_row9_col2" class="data row9 col2" >889</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.pivot_table(data, 'Fare','Pclass',aggfunc=['count', 'sum', 'mean']).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_f72c9_row0_col0 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_f72c9_row0_col1, #T_f72c9_row0_col2, #T_f72c9_row2_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f72c9_row1_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_f72c9_row1_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_f72c9_row1_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_f72c9_row2_col1 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_f72c9_row2_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# </style>
# <table id="T_f72c9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >sum</th>
#       <th class="col_heading level0 col2" >mean</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th class="col_heading level1 col0" >Fare</th>
#       <th class="col_heading level1 col1" >Fare</th>
#       <th class="col_heading level1 col2" >Fare</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f72c9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f72c9_row0_col0" class="data row0 col0" >216</td>
#       <td id="T_f72c9_row0_col1" class="data row0 col1" >18177.412500</td>
#       <td id="T_f72c9_row0_col2" class="data row0 col2" >84.154687</td>
#     </tr>
#     <tr>
#       <th id="T_f72c9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f72c9_row1_col0" class="data row1 col0" >184</td>
#       <td id="T_f72c9_row1_col1" class="data row1 col1" >3801.841700</td>
#       <td id="T_f72c9_row1_col2" class="data row1 col2" >20.662183</td>
#     </tr>
#     <tr>
#       <th id="T_f72c9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f72c9_row2_col0" class="data row2 col0" >491</td>
#       <td id="T_f72c9_row2_col1" class="data row2 col1" >6714.695100</td>
#       <td id="T_f72c9_row2_col2" class="data row2 col2" >13.675550</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(data.Fare)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data[data.Fare > 500]
# Out:
#      PassengerId  Survived  Pclass  ... Parch      Fare  Embarked
# 258          259         1       1  ...     0  512.3292         C
# 679          680         1       1  ...     1  512.3292         C
# 737          738         1       1  ...     0  512.3292         C
#
# [3 rows x 10 columns]

# %% [markdown]
# ## Joint Plot

# %%
sns.jointplot('Age','Fare',data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(data.iloc[:,1:])
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
plt.figure(figsize=(8,6))
sns.violinplot('Sex','Age',hue = 'Survived',data=data,split=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,6))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Count Plot

# %%
f,ax=plt.subplots(1,2,figsize=(18,6))

sns.countplot(data.Survived,hue=data.SibSp,ax=ax[0])
ax[0].set_title('Survived <--> SibSp')
ax[0].legend(loc='upper right')

sns.countplot(data.Survived,hue=data.Parch,ax=ax[1])
ax[1].set_title('Survived <--> Parch')
ax[1].legend(loc='upper right')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Factor Plot

# %%
data.value_counts('Embarked')
# Out:
# Embarked
# S    644
# C    168
# Q     77
# dtype: int64

# %%
sns.factorplot('Embarked','Survived',data=data)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Count Plot

# %%
sns.countplot(data.Age)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %% [markdown]
# ## Hist Plot

# %%
data[['Age']].hist()
plt.show()

# %%
sns.histplot(data=data['Age'])
plt.show()

# %%
data['CategoricalAge'] = pd.cut(data['Age'], 5, precision=0)
data[["CategoricalAge", "Survived"]].groupby('CategoricalAge', as_index = False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   CategoricalAge  Survived
# 0    (0.0, 16.0]  0.550000
# 3   (48.0, 64.0]  0.434783
# 2   (32.0, 48.0]  0.404255
# 1   (16.0, 32.0]  0.369942
# 4   (64.0, 80.0]  0.090909

# %%
sns.countplot(data.Survived,hue=data.CategoricalAge)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Factor Plot

# %%
sns.factorplot('CategoricalAge','Survived',data=data,col='Pclass')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
