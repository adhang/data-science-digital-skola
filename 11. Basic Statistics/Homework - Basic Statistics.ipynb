# %% [markdown]
# <a href="https://colab.research.google.com/github/adhang/data-science-digitalskola/blob/update/11.%20Basic%20Statistics/Homework%20-%20Basic%20Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Basic Statistics
# Author: Adhang Muntaha Muhammad
#
# [![LinkedIn](https://img.shields.io/badge/linkedin-0077B5?style=for-the-badge&logo=linkedin&logoColor=white&link=https://www.linkedin.com/in/adhangmuntaha/)](https://www.linkedin.com/in/adhangmuntaha/)
# [![GitHub](https://img.shields.io/badge/github-121011?style=for-the-badge&logo=github&logoColor=white&link=https://github.com/adhang)](https://github.com/adhang)
# [![Kaggle](https://img.shields.io/badge/kaggle-20BEFF?style=for-the-badge&logo=kaggle&logoColor=white&link=https://www.kaggle.com/adhang)](https://www.kaggle.com/adhang)
# [![Tableau](https://img.shields.io/badge/tableau-E97627?style=for-the-badge&logo=tableau&logoColor=white&link=https://public.tableau.com/app/profile/adhang)](https://public.tableau.com/app/profile/adhang)
# ___
# **Contents**
# 1. Dataset Information
# 2. Importing Libraries
# 3. Reading Dataset
# 4. Dataset Overview
# 5. Basic EDA
# 6. Conclusions

# %% [markdown]
# # 1. Dataset Information
# This dataset is used to predict whether a patient is likely to get a stroke based on the input parameters like gender, age, various diseases, and smoking status. Each row in the data provides relavant information about the patient.
# <br><br>
# **Attribute Information**
# 1. `id` <br>
#     unique identifier
# 2. `gender` <br>
#     - `Male`
#     - `Female`
#     - `Other`
# 3. `age` <br>
#     age of the patient
# 4. `hypertension` <br>
#     - `1` if the patient has hypertension
#     - `0` if the patient doesn't have hypertension
# 5. `heart_disease` <br>
#     - `1` if the patient has a heart disease
#     - `0` if the patient doesn't have any heart diseases
# 6. `ever_married` <br>
#     - `Yes`
#     - `No`
# 7. `work_type` <br>
#     - `children`
#     - `Govt_job`
#     - `Never_worked`
#     - `Private`
#     - `Self-employed`
# 8. `Residence_type` <br>
#     - `Rural`
#     - `Urban`
# 9. `avg_glucose_level` <br>
#     average glucose level in blood
# 10. `bmi` <br>
#     body mass index
# 11. `smoking_status` <br>
#     - `formerly smoked`
#     - `never smoked`
#     - `smokes`
#     - `Unknown` if the information is unavailable for this patient
# 12. `stroke` <br>
#     - `1` if the patient has had a stroke
#     - `0` if the patient has not had a stroke

# %% [markdown]
# # 2. Importing Libraries

# %%
# !pip install empiricaldist
# Out:
# Requirement already satisfied: empiricaldist in /usr/local/lib/python3.7/dist-packages (0.6.2)

# %%
import numpy as np 
import pandas as pd
from empiricaldist import Pmf, Cdf

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rc('patch', edgecolor='black')
sns.set_style('whitegrid')
sns.set_context("notebook", font_scale=1.3, rc={"lines.linewidth": 1.5})

# %% [markdown]
# # 3. Reading Dataset

# %%
path = '/content/drive/MyDrive/Digital Skola/Homework/dataset/healthcare-dataset-stroke-data.csv'

data = pd.read_csv(path)
data.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0   9046    Male  67.0  ...  36.6  formerly smoked      1
# 1  51676  Female  61.0  ...   NaN     never smoked      1
# 2  31112    Male  80.0  ...  32.5     never smoked      1
# 3  60182  Female  49.0  ...  34.4           smokes      1
# 4   1665  Female  79.0  ...  24.0     never smoked      1
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Change to Lower Case
# The `Residence_type` column has uppercase on the first character. I will rename the column name, just to make it more consistent.

# %%
# data.rename(columns={'Residence_type':'residence_type'}, inplace=True)
data.columns = data.columns.str.lower()
data.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0   9046    Male  67.0  ...  36.6  formerly smoked      1
# 1  51676  Female  61.0  ...   NaN     never smoked      1
# 2  31112    Male  80.0  ...  32.5     never smoked      1
# 3  60182  Female  49.0  ...  34.4           smokes      1
# 4   1665  Female  79.0  ...  24.0     never smoked      1
#
# [5 rows x 12 columns]

# %% [markdown]
# There are some datapoints that have upper-case character. Since using upper-case is not necessary in this case, I will change it to be lower-case. At some point, it will prevent me from doing a miss calculation. For example `Urban` and `UrBaN` will be treated as different value (different category for this case) even though they actually have the same meaning.

# %%
column_list = ['gender', 'ever_married', 'work_type', 'residence_type', 'smoking_status']

for col in column_list:
    data[col] = data[col].str.lower()
    
data.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0   9046    male  67.0  ...  36.6  formerly smoked      1
# 1  51676  female  61.0  ...   NaN     never smoked      1
# 2  31112    male  80.0  ...  32.5     never smoked      1
# 3  60182  female  49.0  ...  34.4           smokes      1
# 4   1665  female  79.0  ...  24.0     never smoked      1
#
# [5 rows x 12 columns]

# %% [markdown]
# # 4. Dataset Overview

# %% [markdown]
# ## Data Type

# %%
data_type = pd.DataFrame(data.dtypes).T.rename({0:'data types'})
data_type
# Out:
#                id  gender      age  ...      bmi smoking_status stroke
# data types  int64  object  float64  ...  float64         object  int64
#
# [1 rows x 12 columns]

# %% [markdown]
# ## Total Data

# %%
data_count = pd.DataFrame(data.count()).T.rename({0:'total data'})
data_count
# Out:
#               id  gender   age  ...   bmi  smoking_status  stroke
# total data  5110    5110  5110  ...  4909            5110    5110
#
# [1 rows x 12 columns]

# %% [markdown]
# ## Null Values

# %% [markdown]
# ### Total Null Values

# %%
data_null_total = pd.DataFrame(data.isna().sum()).T.rename({0:'total null'})
data_null_total
# Out:
#             id  gender  age  ...  bmi  smoking_status  stroke
# total null   0       0    0  ...  201               0       0
#
# [1 rows x 12 columns]

# %% [markdown]
# ### Null Values Percentage

# %%
data_null_percentage = pd.DataFrame(100*data.isna().sum()/data.shape[0]).T.rename({0:'percentage null'})
data_null_percentage
# Out:
#                   id  gender  age  ...       bmi  smoking_status  stroke
# percentage null  0.0     0.0  0.0  ...  3.933464             0.0     0.0
#
# [1 rows x 12 columns]

# %% [markdown]
# ## Data Info

# %%
data_info = pd.concat([data_type, data_count, data_null_total, data_null_percentage.round(2)], axis=0)
data_info
# Out:
#                     id  gender      age  ...      bmi smoking_status stroke
# data types       int64  object  float64  ...  float64         object  int64
# total data        5110    5110     5110  ...     4909           5110   5110
# total null           0       0        0  ...      201              0      0
# percentage null    0.0     0.0      0.0  ...     3.93            0.0    0.0
#
# [4 rows x 12 columns]

# %% [markdown]
# It's similar to `info()` method, but in different representation.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# ## Duplicate Values

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Our dataset doesn't have any duplicate values. It's a good sign.

# %% [markdown]
# # 5. Basic EDA

# %% [markdown]
# ## Categorical Data

# %%
data.drop('id', axis=1, inplace=True)

# %%
data.head()
# Out:
#    gender   age  hypertension  ...   bmi   smoking_status stroke
# 0    male  67.0             0  ...  36.6  formerly smoked      1
# 1  female  61.0             0  ...   NaN     never smoked      1
# 2    male  80.0             0  ...  32.5     never smoked      1
# 3  female  49.0             0  ...  34.4           smokes      1
# 4  female  79.0             1  ...  24.0     never smoked      1
#
# [5 rows x 11 columns]

# %% [markdown]
# From this output, we know that some of the attributes are categorical, such as:
# - `gender`
# - `hypertension`
# - `heart_disease`
# - `ever_married`
# - `work_type`
# - `reisdence_type`
# - `smoking_status`
# - `stroke`
#
# Although the description of the dataset has mentioned what the categories of each attribute are, it would be better if we double-checked.

# %%
column_list = ['gender', 'hypertension', 'heart_disease',
               'ever_married', 'work_type', 'residence_type',
               'smoking_status', 'stroke']

# %%
for col in column_list:
  display(pd.DataFrame(data[col].value_counts()).style.background_gradient(vmin=0, subset=col))
# Out:
# <style type="text/css">
# #T_e0e16_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e0e16_row1_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_e0e16_row2_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_e0e16_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >gender</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0e16_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_e0e16_row0_col0" class="data row0 col0" >2994</td>
#     </tr>
#     <tr>
#       <th id="T_e0e16_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_e0e16_row1_col0" class="data row1 col0" >2115</td>
#     </tr>
#     <tr>
#       <th id="T_e0e16_level0_row2" class="row_heading level0 row2" >other</th>
#       <td id="T_e0e16_row2_col0" class="data row2 col0" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f1d9b_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f1d9b_row1_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# </style>
# <table id="T_f1d9b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >hypertension</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1d9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1d9b_row0_col0" class="data row0 col0" >4612</td>
#     </tr>
#     <tr>
#       <th id="T_f1d9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1d9b_row1_col0" class="data row1 col0" >498</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0a6e3_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0a6e3_row1_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_0a6e3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >heart_disease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a6e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a6e3_row0_col0" class="data row0 col0" >4834</td>
#     </tr>
#     <tr>
#       <th id="T_0a6e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a6e3_row1_col0" class="data row1 col0" >276</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b952c_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b952c_row1_col0 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b952c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ever_married</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b952c_level0_row0" class="row_heading level0 row0" >yes</th>
#       <td id="T_b952c_row0_col0" class="data row0 col0" >3353</td>
#     </tr>
#     <tr>
#       <th id="T_b952c_level0_row1" class="row_heading level0 row1" >no</th>
#       <td id="T_b952c_row1_col0" class="data row1 col0" >1757</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_43557_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_43557_row1_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_43557_row2_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_43557_row3_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_43557_row4_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_43557_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >work_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43557_level0_row0" class="row_heading level0 row0" >private</th>
#       <td id="T_43557_row0_col0" class="data row0 col0" >2925</td>
#     </tr>
#     <tr>
#       <th id="T_43557_level0_row1" class="row_heading level0 row1" >self-employed</th>
#       <td id="T_43557_row1_col0" class="data row1 col0" >819</td>
#     </tr>
#     <tr>
#       <th id="T_43557_level0_row2" class="row_heading level0 row2" >children</th>
#       <td id="T_43557_row2_col0" class="data row2 col0" >687</td>
#     </tr>
#     <tr>
#       <th id="T_43557_level0_row3" class="row_heading level0 row3" >govt_job</th>
#       <td id="T_43557_row3_col0" class="data row3 col0" >657</td>
#     </tr>
#     <tr>
#       <th id="T_43557_level0_row4" class="row_heading level0 row4" >never_worked</th>
#       <td id="T_43557_row4_col0" class="data row4 col0" >22</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1a4f8_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1a4f8_row1_col0 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a4f8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >residence_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a4f8_level0_row0" class="row_heading level0 row0" >urban</th>
#       <td id="T_1a4f8_row0_col0" class="data row0 col0" >2596</td>
#     </tr>
#     <tr>
#       <th id="T_1a4f8_level0_row1" class="row_heading level0 row1" >rural</th>
#       <td id="T_1a4f8_row1_col0" class="data row1 col0" >2514</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b5142_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b5142_row1_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_b5142_row2_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_b5142_row3_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# </style>
# <table id="T_b5142_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >smoking_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5142_level0_row0" class="row_heading level0 row0" >never smoked</th>
#       <td id="T_b5142_row0_col0" class="data row0 col0" >1892</td>
#     </tr>
#     <tr>
#       <th id="T_b5142_level0_row1" class="row_heading level0 row1" >unknown</th>
#       <td id="T_b5142_row1_col0" class="data row1 col0" >1544</td>
#     </tr>
#     <tr>
#       <th id="T_b5142_level0_row2" class="row_heading level0 row2" >formerly smoked</th>
#       <td id="T_b5142_row2_col0" class="data row2 col0" >885</td>
#     </tr>
#     <tr>
#       <th id="T_b5142_level0_row3" class="row_heading level0 row3" >smokes</th>
#       <td id="T_b5142_row3_col0" class="data row3 col0" >789</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8a56d_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_8a56d_row1_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_8a56d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >stroke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a56d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a56d_row0_col0" class="data row0 col0" >4861</td>
#     </tr>
#     <tr>
#       <th id="T_8a56d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a56d_row1_col0" class="data row1 col0" >249</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It's not really a plot, but a table with color gradations like this one can give us insight into the distribution of categories. The darker it is, the more data in the category.

# %% [markdown]
# ### Probability Mass Function
# The categorical data only contain a few categories, so we can use the probability mass function to see the distribution of categories.

# %%
for col in column_list:
  pmf_data = Pmf.from_seq(data[col], normalize=True)
  pmf_data = pd.DataFrame({col:pmf_data.index, 'pmf':pmf_data.values})
  pmf_data.set_index(col, inplace=True)
  display(pmf_data.style.background_gradient(vmin=0, subset='pmf'))
  print('\n')
# Out:
# <style type="text/css">
# #T_820ad_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_820ad_row1_col0 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_820ad_row2_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_820ad_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820ad_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_820ad_row0_col0" class="data row0 col0" >0.585910</td>
#     </tr>
#     <tr>
#       <th id="T_820ad_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_820ad_row1_col0" class="data row1 col0" >0.413894</td>
#     </tr>
#     <tr>
#       <th id="T_820ad_level0_row2" class="row_heading level0 row2" >other</th>
#       <td id="T_820ad_row2_col0" class="data row2 col0" >0.000196</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b0165_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b0165_row1_col0 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# </style>
# <table id="T_b0165_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hypertension</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0165_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0165_row0_col0" class="data row0 col0" >0.902544</td>
#     </tr>
#     <tr>
#       <th id="T_b0165_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b0165_row1_col0" class="data row1 col0" >0.097456</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f1986_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f1986_row1_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_f1986_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >heart_disease</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1986_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1986_row0_col0" class="data row0 col0" >0.945988</td>
#     </tr>
#     <tr>
#       <th id="T_f1986_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1986_row1_col0" class="data row1 col0" >0.054012</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a4fb8_row0_col0 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_a4fb8_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a4fb8_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ever_married</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4fb8_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_a4fb8_row0_col0" class="data row0 col0" >0.343836</td>
#     </tr>
#     <tr>
#       <th id="T_a4fb8_level0_row1" class="row_heading level0 row1" >yes</th>
#       <td id="T_a4fb8_row1_col0" class="data row1 col0" >0.656164</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e95de_row0_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e95de_row1_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_e95de_row2_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e95de_row3_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e95de_row4_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# </style>
# <table id="T_e95de_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >work_type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e95de_level0_row0" class="row_heading level0 row0" >children</th>
#       <td id="T_e95de_row0_col0" class="data row0 col0" >0.134442</td>
#     </tr>
#     <tr>
#       <th id="T_e95de_level0_row1" class="row_heading level0 row1" >govt_job</th>
#       <td id="T_e95de_row1_col0" class="data row1 col0" >0.128571</td>
#     </tr>
#     <tr>
#       <th id="T_e95de_level0_row2" class="row_heading level0 row2" >never_worked</th>
#       <td id="T_e95de_row2_col0" class="data row2 col0" >0.004305</td>
#     </tr>
#     <tr>
#       <th id="T_e95de_level0_row3" class="row_heading level0 row3" >private</th>
#       <td id="T_e95de_row3_col0" class="data row3 col0" >0.572407</td>
#     </tr>
#     <tr>
#       <th id="T_e95de_level0_row4" class="row_heading level0 row4" >self-employed</th>
#       <td id="T_e95de_row4_col0" class="data row4 col0" >0.160274</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_10149_row0_col0 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_10149_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_10149_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >residence_type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10149_level0_row0" class="row_heading level0 row0" >rural</th>
#       <td id="T_10149_row0_col0" class="data row0 col0" >0.491977</td>
#     </tr>
#     <tr>
#       <th id="T_10149_level0_row1" class="row_heading level0 row1" >urban</th>
#       <td id="T_10149_row1_col0" class="data row1 col0" >0.508023</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_563b7_row0_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_563b7_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_563b7_row2_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_563b7_row3_col0 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_563b7_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >smoking_status</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_563b7_level0_row0" class="row_heading level0 row0" >formerly smoked</th>
#       <td id="T_563b7_row0_col0" class="data row0 col0" >0.173190</td>
#     </tr>
#     <tr>
#       <th id="T_563b7_level0_row1" class="row_heading level0 row1" >never smoked</th>
#       <td id="T_563b7_row1_col0" class="data row1 col0" >0.370254</td>
#     </tr>
#     <tr>
#       <th id="T_563b7_level0_row2" class="row_heading level0 row2" >smokes</th>
#       <td id="T_563b7_row2_col0" class="data row2 col0" >0.154403</td>
#     </tr>
#     <tr>
#       <th id="T_563b7_level0_row3" class="row_heading level0 row3" >unknown</th>
#       <td id="T_563b7_row3_col0" class="data row3 col0" >0.302153</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_54d54_row0_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_54d54_row1_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_54d54_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pmf</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >stroke</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54d54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54d54_row0_col0" class="data row0 col0" >0.951272</td>
#     </tr>
#     <tr>
#       <th id="T_54d54_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54d54_row1_col0" class="data row1 col0" >0.048728</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(3, 3, figsize=(12,12))
axes_list = [axes for axes_row in ax for axes in axes_row]

for i, col in enumerate(column_list):
  pmf_data = Pmf.from_seq(data[col], normalize=True)
  pmf_data = pd.DataFrame({col:pmf_data.index, 'pmf':pmf_data})

  sns.barplot(data=pmf_data, x=col, y='pmf', ax=axes_list[i])
  axes_list[i].set_title(f'PMF of {col}')
  axes_list[i].set_xlabel('')
  axes_list[i].set_ylabel('')
  plt.setp(axes_list[i].get_xticklabels(), rotation='vertical')

axes_list[-1].set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# From this plot, we can see that:
# - On the `gender` plot, the `other` category is barely visible because it only has 1 patient
# - Based on `hypertension` plot, most of patient doesn't have hypertension
# - Based on `heart_disease` plot, most of patient doesn't have heart disease
# - On the `work_type` plot, the `never_worked` category is barely visible because it only contains 0.4% of the total patients
# - On the `stroke` plot, which is the target attribute, the category distribution is not balanced

# %% [markdown]
# ### Pivot Table
# I'm just curious, so I'll try to find out how many patients that don't have any comorbidities, only have hypertension, only have heart disease, or have both hypertension and heart disease.

# %%
pd.crosstab(index=[data['hypertension'], data['heart_disease']],
            columns=data['stroke'], margins=True).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_14ca6_row0_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_14ca6_row0_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_14ca6_row0_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_14ca6_row1_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_14ca6_row1_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_14ca6_row1_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_14ca6_row2_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_14ca6_row2_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_14ca6_row2_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_14ca6_row3_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_14ca6_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_14ca6_row3_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_14ca6_row4_col0, #T_14ca6_row4_col1, #T_14ca6_row4_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_14ca6_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >stroke</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hypertension</th>
#       <th class="index_name level1" >heart_disease</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14ca6_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_14ca6_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_14ca6_row0_col0" class="data row0 col0" >4251</td>
#       <td id="T_14ca6_row0_col1" class="data row0 col1" >149</td>
#       <td id="T_14ca6_row0_col2" class="data row0 col2" >4400</td>
#     </tr>
#     <tr>
#       <th id="T_14ca6_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_14ca6_row1_col0" class="data row1 col0" >178</td>
#       <td id="T_14ca6_row1_col1" class="data row1 col1" >34</td>
#       <td id="T_14ca6_row1_col2" class="data row1 col2" >212</td>
#     </tr>
#     <tr>
#       <th id="T_14ca6_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_14ca6_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_14ca6_row2_col0" class="data row2 col0" >381</td>
#       <td id="T_14ca6_row2_col1" class="data row2 col1" >53</td>
#       <td id="T_14ca6_row2_col2" class="data row2 col2" >434</td>
#     </tr>
#     <tr>
#       <th id="T_14ca6_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_14ca6_row3_col0" class="data row3 col0" >51</td>
#       <td id="T_14ca6_row3_col1" class="data row3 col1" >13</td>
#       <td id="T_14ca6_row3_col2" class="data row3 col2" >64</td>
#     </tr>
#     <tr>
#       <th id="T_14ca6_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_14ca6_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_14ca6_row4_col0" class="data row4 col0" >4861</td>
#       <td id="T_14ca6_row4_col1" class="data row4 col1" >249</td>
#       <td id="T_14ca6_row4_col2" class="data row4 col2" >5110</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From this pivot table, we can see that most patients didn't have any comorbidities.

# %%
pd.crosstab(index=[data['hypertension'], data['heart_disease']],
            columns=data['stroke'], margins=True, normalize=True).round(3).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_ce112_row0_col0 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_ce112_row0_col1 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_ce112_row0_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_ce112_row1_col0 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_ce112_row1_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_ce112_row1_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_ce112_row2_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_ce112_row2_col1 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_ce112_row2_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ce112_row3_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_ce112_row3_col1 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_ce112_row3_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ce112_row4_col0, #T_ce112_row4_col1, #T_ce112_row4_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce112_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >stroke</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hypertension</th>
#       <th class="index_name level1" >heart_disease</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce112_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_ce112_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_ce112_row0_col0" class="data row0 col0" >0.832000</td>
#       <td id="T_ce112_row0_col1" class="data row0 col1" >0.029000</td>
#       <td id="T_ce112_row0_col2" class="data row0 col2" >0.861000</td>
#     </tr>
#     <tr>
#       <th id="T_ce112_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_ce112_row1_col0" class="data row1 col0" >0.035000</td>
#       <td id="T_ce112_row1_col1" class="data row1 col1" >0.007000</td>
#       <td id="T_ce112_row1_col2" class="data row1 col2" >0.041000</td>
#     </tr>
#     <tr>
#       <th id="T_ce112_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_ce112_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_ce112_row2_col0" class="data row2 col0" >0.075000</td>
#       <td id="T_ce112_row2_col1" class="data row2 col1" >0.010000</td>
#       <td id="T_ce112_row2_col2" class="data row2 col2" >0.085000</td>
#     </tr>
#     <tr>
#       <th id="T_ce112_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_ce112_row3_col0" class="data row3 col0" >0.010000</td>
#       <td id="T_ce112_row3_col1" class="data row3 col1" >0.003000</td>
#       <td id="T_ce112_row3_col2" class="data row3 col2" >0.013000</td>
#     </tr>
#     <tr>
#       <th id="T_ce112_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_ce112_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_ce112_row4_col0" class="data row4 col0" >0.951000</td>
#       <td id="T_ce112_row4_col1" class="data row4 col1" >0.049000</td>
#       <td id="T_ce112_row4_col2" class="data row4 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Most patients didn't have any comorbidities
# - Most patients didn't have stroke
# - The category distribution is not balanced. Most of patient doesn't get stroke. Only about 5% of patients have a stroke.

# %%
pd.crosstab(index=data['residence_type'],
            columns=data['stroke'], normalize=True).round(3).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_064d2_row0_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_064d2_row0_col1 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_064d2_row1_col0, #T_064d2_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_064d2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stroke</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >residence_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_064d2_level0_row0" class="row_heading level0 row0" >rural</th>
#       <td id="T_064d2_row0_col0" class="data row0 col0" >0.470000</td>
#       <td id="T_064d2_row0_col1" class="data row0 col1" >0.022000</td>
#     </tr>
#     <tr>
#       <th id="T_064d2_level0_row1" class="row_heading level0 row1" >urban</th>
#       <td id="T_064d2_row1_col0" class="data row1 col0" >0.482000</td>
#       <td id="T_064d2_row1_col1" class="data row1 col1" >0.026000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From this pivot table, we know that the distribution between residence type is balanced.

# %%
pd.crosstab(index=data['smoking_status'],
            columns=data['stroke'], normalize=True).round(3).style.background_gradient(vmin=0)
# Out:
# <style type="text/css">
# #T_95e7a_row0_col0 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_95e7a_row0_col1 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_95e7a_row1_col0, #T_95e7a_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_95e7a_row2_col0 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_95e7a_row2_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_95e7a_row3_col0 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_95e7a_row3_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_95e7a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >stroke</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >smoking_status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95e7a_level0_row0" class="row_heading level0 row0" >formerly smoked</th>
#       <td id="T_95e7a_row0_col0" class="data row0 col0" >0.159000</td>
#       <td id="T_95e7a_row0_col1" class="data row0 col1" >0.014000</td>
#     </tr>
#     <tr>
#       <th id="T_95e7a_level0_row1" class="row_heading level0 row1" >never smoked</th>
#       <td id="T_95e7a_row1_col0" class="data row1 col0" >0.353000</td>
#       <td id="T_95e7a_row1_col1" class="data row1 col1" >0.018000</td>
#     </tr>
#     <tr>
#       <th id="T_95e7a_level0_row2" class="row_heading level0 row2" >smokes</th>
#       <td id="T_95e7a_row2_col0" class="data row2 col0" >0.146000</td>
#       <td id="T_95e7a_row2_col1" class="data row2 col1" >0.008000</td>
#     </tr>
#     <tr>
#       <th id="T_95e7a_level0_row3" class="row_heading level0 row3" >unknown</th>
#       <td id="T_95e7a_row3_col0" class="data row3 col0" >0.293000</td>
#       <td id="T_95e7a_row3_col1" class="data row3 col1" >0.009000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Surprisingly, most of the stroke patients had never smoked before. But, as I already mentioned, the `stroke` attribute is not balanced. So that it can lead to bias, because we know that smoking is not good for our health.
# <br><br>
# But yes, our knowledge (that smoking is not good for our health) can also bias our analysis.

# %% [markdown]
# ### Bar Plot
# From the previous pivot table, we can understand the distribution of the data. However, some people (especially those who are not technically savvy) may not understand "What does 0 mean? What about 1?" on the index or column name. So, I'm going to visualize it using the plot bar.
# <br><br>
# Also, providing a pivot table full of numbers can sometimes be overwhelming for others.

# %%
# creating the logical conditions
conditions = [ ~(data['hypertension'] | data['heart_disease']).astype(bool),
              ((data['hypertension'] == 1) & (data['heart_disease'] == 0)).astype(bool),
              ((data['hypertension'] == 0) & (data['heart_disease'] == 1)).astype(bool),
              (data['hypertension'] & data['heart_disease']).astype(bool)]

# values for each conditions (if True)
values = ['No Comorbidities', 'Only Hypertension', 'Only Heart Disease', 'Both Comorbidities']

# assign the condition and the values
disease_check = np.select(conditions, values)
disease_category = pd.Series(disease_check)

# %%
mapping = {val: i for i, val in enumerate(values)}
key = disease_category.map(mapping)
# disease_category = disease_category.iloc[key.argsort()]

plt.figure(figsize=(12,6))
ax = sns.countplot(x=disease_category.iloc[key.argsort()])
# plt.xticks(rotation=45)
plt.setp(ax.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# Just like on the pivot table, we can see that most patients ddin't have any comorbidities.

# %%
# create a new attribute
data['disease_category'] = disease_category

# change it to categorical data type, and sort it (just for better viz on the next step)
data['disease_category'] = data['disease_category'].astype('category')
data['disease_category'] = data['disease_category'].cat.set_categories(values)
data['disease_category'] = data['disease_category'].cat.set_categories(values)
data.sort_values(['disease_category'])

# plot the distribution of each category
plt.figure(figsize=(12,6))
# sns.histplot(data=data, x='disease_category', hue='stroke', multiple='stack').set_xlabel('')
# sns.histplot(data=data, x='disease_category', stat='density', hue='stroke', multiple='stack').set_xlabel('')
sns.countplot(data=data, x='disease_category', hue='stroke').set_xlabel('')
plt.show()

# %% [markdown]
# The percentage of patient who had stroke is small,  it's beacause the data distribution on `stroke` attribute is not balanced. Most of patient doesn't get stroke.

# %%
data_stroke = data[(data['stroke'] == 1)]
data_stroke['disease_category'].value_counts()/data['disease_category'].value_counts()
# Out:
# No Comorbidities      0.033864
# Only Hypertension     0.122120
# Only Heart Disease    0.160377
# Both Comorbidities    0.203125
# Name: disease_category, dtype: float64

# %% [markdown]
# ### Pie Chart
# Another way to see the portion of categories is using a pie chart. But, we must be very careful when using this chart type. Sometimes, it makes our visualization being ambiguous.

# %%
pie_data = disease_category.value_counts(normalize=True).values * 100
pie_label = [f'{l} ({s:0.1f}%)' for l, s in zip(values, pie_data)]

plt.figure(figsize=(12,6))
wedges, texts = plt.pie(pie_data, startangle=0, explode=[0.1, 0, 0, 0])
plt.axis('equal')
plt.legend(wedges, pie_label, title='Patient Comorbidities', loc='upper left', bbox_to_anchor=(1,0,0.5,1))
plt.tight_layout()
plt.show()

# %% [markdown]
# As we have seen, most patients have no comorbidities. Using a pie chart is good if it can clearly tell us about the portion of the data.

# %% [markdown]
# ## Numerical Data
# For numerical data, we can use histogram and kde (kernel density estimator) to see the data distribution and density.

# %%
data.head()
# Out:
#    gender   age  hypertension  ...   smoking_status stroke    disease_category
# 0    male  67.0             0  ...  formerly smoked      1  Only Heart Disease
# 1  female  61.0             0  ...     never smoked      1    No Comorbidities
# 2    male  80.0             0  ...     never smoked      1  Only Heart Disease
# 3  female  49.0             0  ...           smokes      1    No Comorbidities
# 4  female  79.0             1  ...     never smoked      1   Only Hypertension
#
# [5 rows x 12 columns]

# %% [markdown]
# From this output, we know that some of the attributes are numerical, such as:
# - `age`
# - `avg_glucose_level`
# - `bmi`

# %% [markdown]
# ### Histogram

# %%
column_list = ['age', 'avg_glucose_level', 'bmi']

fig, ax = plt.subplots(1, 3, figsize=(12,6))

for i, col in enumerate(column_list):
  sns.histplot(data=data, x=col, hue='stroke', multiple='stack', ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Our dataset does not appear to be in a normal distribution, especially the `avg_glucose_level` and `bmi` attributes which have a right skewed form.

# %% [markdown]
# ### Density

# %%
fig, ax = plt.subplots(1, 3, figsize=(18,6))

for i, col in enumerate(column_list):
  sns.kdeplot(data=data, x=col, linewidth=3, hue='stroke', fill=True, multiple='stack', ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# With one glance, we can see that most patients who have a stroke are around the age of 60-80.

# %% [markdown]
# ### Histogram Density
# It's just another way to see histogram and kde plot at the same time.

# %%
column_list = ['age', 'avg_glucose_level', 'bmi']

fig, ax = plt.subplots(1, 3, figsize=(12,6))

for i, col in enumerate(column_list):
  sns.histplot(data=data, x=col, stat='density', hue='stroke', multiple='stack', ax=ax[i])
  sns.kdeplot(data=data, x=col, linewidth=3, hue='stroke', fill=False, multiple='stack', ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box Plot
# Box plot is very useful to see outliers on our dataset.

# %%
column_list = ['age', 'avg_glucose_level', 'bmi']

fig, ax = plt.subplots(1, 3, figsize=(12,6))

for i, col in enumerate(column_list):
  sns.boxplot(data=data, x=col, ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Using box plot, we can see there are many outliers on the `avg_glucose_level` and `bmi` attributes.

# %%
column_list = ['age', 'avg_glucose_level', 'bmi']

fig, ax = plt.subplots(1, 3, figsize=(12,6))

for i, col in enumerate(column_list):
  sns.boxplot(data=data, x='stroke', y=col, ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# If we divide the data based on the `stroke` attribute, we get some important insights:
# - Most patients who have had a stroke are over the age of 60.
# - But, it's still possible that younger people can also experience it, as we can see there are some outliers
# - We can assume that the age of the patient has a correlation whether the patient had a stroke or not

# %% [markdown]
# ### Scatter Plot
# Scatter plot is usually used to see the correlation between attributes. Let's say, we want to know the correlation between:
# - patients age and average glucose level
# - patients age and bmi

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))

sns.scatterplot(data=data, x='age', y='avg_glucose_level', ax=ax[0])
sns.scatterplot(data=data, x='age', y='bmi', ax=ax[1])

plt.show()

# %% [markdown]
# From this scatter plot, we can't recognize any correlation between `age` and `avg_glucose_level`. However, `age` and `bmi` seem to have a correlation.

# %% [markdown]
# ### Regression Plot
# Regression plot is intended to add a visual guide that helps to emphasize patterns in a dataset.

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))

sns.regplot(data=data, x='age', y='avg_glucose_level', ax=ax[0], line_kws={'linewidth':3, 'color':'r'})
sns.regplot(data=data, x='age', y='bmi', ax=ax[1], line_kws={'linewidth':3, 'color':'r'})

plt.show()

# %% [markdown]
# As we can see, a single straight line (from first-order linear regression) can't describe our dataset pattern. The `age` and `bmi` plot seems to have a curved pattern, so I will try to use the second order.
#
# **Note:** I'm just plotting a curve for seeking a pattern, not a correlation. Because correlation is defined with a straight line.

# %%
plt.figure(figsize=(12,12))
sns.lmplot(data=data, x='age', y='bmi', order=2, line_kws={'linewidth':3, 'color':'r'})

plt.show()

# %% [markdown]
# From this plot, we can see that the line forms a curve. We can assume that patients' age has a relationship with BMI.

# %% [markdown]
# ### Contour Plot
# Using scatter plot, our data most likely to be overplotting. To avoid that, we can use contour plot.

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,12))

sns.kdeplot(data=data, x='age', y='avg_glucose_level', ax=ax[0,0])
sns.kdeplot(data=data, x='age', y='bmi', ax=ax[0,1])

sns.kdeplot(data=data, x='age', y='avg_glucose_level', cmap='Blues', shade=True, thresh=0, ax=ax[1,0])
sns.kdeplot(data=data, x='age', y='bmi', cmap='Blues', shade=True, thresh=0, ax=ax[1,1])

plt.show()

# %% [markdown]
# By using a contour plot, we can find out where the datapoints tend to cluster.

# %% [markdown]
# ### Heatmap
# Another way to see correlation is using heatmap.

# %%
corr_matrix = data.corr().round(2)

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

plt.figure(figsize=(6,6))
sns.heatmap(corr_matrix, center=0, vmin=-1, vmax=1, mask=mask, annot=True, cmap='BrBG')
plt.show()

# %% [markdown]
# Using heatmap, we can exactly understand the correlation value. As we can see in the last row, the attribute that has the highest correlation with `stroke` is the patients' age. Even though it's not really high, because it's closer to 0 than 1.
# <br><br>
# This heatmap also confirms my assumption that `age` and `bmi` have a relationship. Surprisingly, that is the highest correlation.

# %% [markdown]
# ### Joint Plot
# Joint plot is used to view histogram and scatter plot at once.

# %%
plt.figure(figsize=(12,6))
sns.jointplot(data=data, x='age', y='avg_glucose_level')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.jointplot(data=data, x='age', y='bmi')
plt.show()

# %% [markdown]
# ### Pair Plot
# This is another way to see the distribution of data. This plot also contains multiple histograms and scatter plots at once.

# %%
sns.pairplot(data=data, hue='stroke')
plt.show()

# %% [markdown]
# Since our dataset contains many categorical values, it's hard to interpret the whole plot.

# %% [markdown]
# ### Violin Plot
# Simply, it's like a combination of a boxplot and density plot.

# %%
column_list = ['age', 'avg_glucose_level', 'bmi']

fig, ax = plt.subplots(1, 3, figsize=(12,6))

for i, col in enumerate(column_list):
  sns.violinplot(data=data, x='stroke', y=col, ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# - The thinner the body of the violin, the less data it contains.
# - At some point, it might just be a line. I'm not really sure, but I think it's the outliers.

# %% [markdown]
# # 6. Conclusions
# So far, some conclusions for this dataset:
# - Most patients didn't have comorbidities (hypertension and or heart disease)
# - This dataset target (`stroke`) is not balanced. So, it will affect the performance of machine learning predictions. We can use oversampling, undersampling, or SMOTE to handle this problem.
# - The numerical data does not appear to be in a normal distribution, especially the `avg_glucose_level` and `bmi` attributes which have a right-skewed form. We can use log transform, square root transform, or box-cox transform for handling skewed data.
# - The numerical data has many outliers, especially on the `avg_glucose_level` and `bmi` attributes. It needs more diagnostic to determine whether we will keep the outliers or remove the outliers.
